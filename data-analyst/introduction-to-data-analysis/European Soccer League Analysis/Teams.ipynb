# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
con = sqlite3.connect("./database.sqlite")

# %%
teams = pd.read_sql_query("SELECT * FROM Team", con=con)
teams_attributes = pd.read_sql_query("SELECT * FROM Team_Attributes", con=con)

# %%
teams
# Out:
#         id  team_api_id  team_fifa_api_id      team_long_name team_short_name
# 0        1         9987             673.0            KRC Genk             GEN
# 1        2         9993             675.0        Beerschot AC             BAC
# 2        3        10000           15005.0    SV Zulte-Waregem             ZUL
# 3        4         9994            2007.0    Sporting Lokeren             LOK
# 4        5         9984            1750.0   KSV Cercle Brugge             CEB
# ..     ...          ...               ...                 ...             ...
# 294  49479        10190             898.0       FC St. Gallen             GAL
# 295  49837        10191            1715.0             FC Thun             THU
# 296  50201         9777             324.0         Servette FC             SER
# 297  50204         7730            1862.0  FC Lausanne-Sports             LAU
# 298  51606         7896               NaN              Lugano             LUG
#
# [299 rows x 5 columns]

# %% [markdown]
# Drop some columns from 'teams' dataframe that are not necessary for our analysis.

# %%
teams.drop(columns=["id", "team_fifa_api_id", "team_short_name"], inplace=True)
teams
# Out:
#      team_api_id      team_long_name
# 0           9987            KRC Genk
# 1           9993        Beerschot AC
# 2          10000    SV Zulte-Waregem
# 3           9994    Sporting Lokeren
# 4           9984   KSV Cercle Brugge
# ..           ...                 ...
# 294        10190       FC St. Gallen
# 295        10191             FC Thun
# 296         9777         Servette FC
# 297         7730  FC Lausanne-Sports
# 298         7896              Lugano
#
# [299 rows x 2 columns]

# %% [markdown]
# Check the NA values and uniqueness for this dataset

# %%
teams.isna().sum()
# Out:
# team_api_id       0
# team_long_name    0
# dtype: int64

# %% [markdown]
# With this we verify that we are working with a dataset with non-null values.
#
# Let's check the uniqueness of the values. For this dataset it is important to verify the uniqueness since we are working with IDs and obviously all of them should be different in the first place.

# %%
teams.apply(lambda x: print(f"'{x.name}' is unique: {x.is_unique}"))
# Out:
# 'team_api_id' is unique: True
# 'team_long_name' is unique: False
# team_api_id       None
# team_long_name    None
# dtype: object

# %% [markdown]
# Given the results we can see the IDs are different but we have duplicated team's names, which means some teams were stored with different IDs. Let's check that out!

# %%
teams.loc[teams["team_long_name"].duplicated(), :]
# Out:
#      team_api_id        team_long_name
# 24        274581  Royal Excel Mouscron
# 183         8020         Polonia Bytom
# 199         8024           Widzew Łódź

# %% [markdown]
# We've found the teams that are duplicated. Let's analyze their data in the 'teams_attributes' dataframe.
#
# First, we're going to add a column with the team's name to 'teams_attributes' dataframe.

# %%
teams_attributes
# Out:
#         id  team_fifa_api_id  team_api_id                 date  \
# 0        1               434         9930  2010-02-22 00:00:00
# 1        2               434         9930  2014-09-19 00:00:00
# 2        3               434         9930  2015-09-10 00:00:00
# 3        4                77         8485  2010-02-22 00:00:00
# 4        5                77         8485  2011-02-22 00:00:00
# ...    ...               ...          ...                  ...
# 1453  1454             15005        10000  2011-02-22 00:00:00
# 1454  1455             15005        10000  2012-02-22 00:00:00
# 1455  1456             15005        10000  2013-09-20 00:00:00
# 1456  1457             15005        10000  2014-09-19 00:00:00
# 1457  1458             15005        10000  2015-09-10 00:00:00
#
#       buildUpPlaySpeed buildUpPlaySpeedClass  buildUpPlayDribbling  \
# 0                   60              Balanced                   NaN
# 1                   52              Balanced                  48.0
# 2                   47              Balanced                  41.0
# 3                   70                  Fast                   NaN
# 4                   47              Balanced                   NaN
# ...                ...                   ...                   ...
# 1453                52              Balanced                   NaN
# 1454                54              Balanced                   NaN
# 1455                54              Balanced                   NaN
# 1456                54              Balanced                  42.0
# 1457                54              Balanced                  42.0
#
#      buildUpPlayDribblingClass  buildUpPlayPassing buildUpPlayPassingClass  \
# 0                       Little                  50                   Mixed
# 1                       Normal                  56                   Mixed
# 2                       Normal                  54                   Mixed
# 3                       Little                  70                    Long
# 4                       Little                  52                   Mixed
# ...                        ...                 ...                     ...
# 1453                    Little                  52                   Mixed
# 1454                    Little                  51                   Mixed
# 1455                    Little                  51                   Mixed
# 1456                    Normal                  51                   Mixed
# 1457                    Normal                  51                   Mixed
#
#       ... chanceCreationShooting  chanceCreationShootingClass  \
# 0     ...                     55                       Normal
# 1     ...                     64                       Normal
# 2     ...                     64                       Normal
# 3     ...                     70                         Lots
# 4     ...                     52                       Normal
# ...   ...                    ...                          ...
# 1453  ...                     53                       Normal
# 1454  ...                     50                       Normal
# 1455  ...                     32                       Little
# 1456  ...                     32                       Little
# 1457  ...                     32                       Little
#
#      chanceCreationPositioningClass  defencePressure defencePressureClass  \
# 0                         Organised               50               Medium
# 1                         Organised               47               Medium
# 2                         Organised               47               Medium
# 3                         Organised               60               Medium
# 4                         Organised               47               Medium
# ...                             ...              ...                  ...
# 1453                      Organised               46               Medium
# 1454                      Organised               44               Medium
# 1455                      Organised               44               Medium
# 1456                      Organised               44               Medium
# 1457                      Organised               44               Medium
#
#       defenceAggression defenceAggressionClass defenceTeamWidth  \
# 0                    55                  Press               45
# 1                    44                  Press               54
# 2                    44                  Press               54
# 3                    70                 Double               70
# 4                    47                  Press               52
# ...                 ...                    ...              ...
# 1453                 48                  Press               53
# 1454                 55                  Press               53
# 1455                 58                  Press               37
# 1456                 58                  Press               37
# 1457                 58                  Press               37
#
#       defenceTeamWidthClass defenceDefenderLineClass
# 0                    Normal                    Cover
# 1                    Normal                    Cover
# 2                    Normal                    Cover
# 3                      Wide                    Cover
# 4                    Normal                    Cover
# ...                     ...                      ...
# 1453                 Normal                    Cover
# 1454                 Normal                    Cover
# 1455                 Normal                    Cover
# 1456                 Normal                    Cover
# 1457                 Normal                    Cover
#
# [1458 rows x 25 columns]

# %%
teams_attributes = pd.merge(
    teams,
    teams_attributes,
    on=["team_api_id"],
)
teams_attributes
# Out:
#       team_api_id      team_long_name    id  team_fifa_api_id  \
# 0            9987            KRC Genk   485               673
# 1            9987            KRC Genk   486               673
# 2            9987            KRC Genk   487               673
# 3            9987            KRC Genk   488               673
# 4            9987            KRC Genk   489               673
# ...           ...                 ...   ...               ...
# 1453         9777         Servette FC  1156               324
# 1454         7730  FC Lausanne-Sports   672              1862
# 1455         7730  FC Lausanne-Sports   673              1862
# 1456         7730  FC Lausanne-Sports   674              1862
# 1457         7730  FC Lausanne-Sports   675              1862
#
#                      date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# 0     2010-02-22 00:00:00                45              Balanced
# 1     2011-02-22 00:00:00                66              Balanced
# 2     2012-02-22 00:00:00                53              Balanced
# 3     2013-09-20 00:00:00                58              Balanced
# 4     2014-09-19 00:00:00                58              Balanced
# ...                   ...               ...                   ...
# 1453  2013-09-20 00:00:00                48              Balanced
# 1454  2010-02-22 00:00:00                30                  Slow
# 1455  2012-02-22 00:00:00                37              Balanced
# 1456  2013-09-20 00:00:00                51              Balanced
# 1457  2014-09-19 00:00:00                37              Balanced
#
#       buildUpPlayDribbling buildUpPlayDribblingClass  buildUpPlayPassing  ...  \
# 0                      NaN                    Little                  45  ...
# 1                      NaN                    Little                  52  ...
# 2                      NaN                    Little                  55  ...
# 3                      NaN                    Little                  38  ...
# 4                     52.0                    Normal                  38  ...
# ...                    ...                       ...                 ...  ...
# 1453                   NaN                    Little                  51  ...
# 1454                   NaN                    Little                  60  ...
# 1455                   NaN                    Little                  49  ...
# 1456                   NaN                    Little                  49  ...
# 1457                  55.0                    Normal                  49  ...
#
#      chanceCreationShooting chanceCreationShootingClass  \
# 0                        60                      Normal
# 1                        51                      Normal
# 2                        56                      Normal
# 3                        56                      Normal
# 4                        56                      Normal
# ...                     ...                         ...
# 1453                     45                      Normal
# 1454                     60                      Normal
# 1455                     48                      Normal
# 1456                     48                      Normal
# 1457                     52                      Normal
#
#       chanceCreationPositioningClass defencePressure  defencePressureClass  \
# 0                          Organised              70                  High
# 1                          Organised              48                Medium
# 2                          Organised              47                Medium
# 3                          Organised              47                Medium
# 4                          Organised              47                Medium
# ...                              ...             ...                   ...
# 1453                       Organised              49                Medium
# 1454                       Organised              55                Medium
# 1455                       Organised              43                Medium
# 1456                       Organised              43                Medium
# 1457                       Organised              46                Medium
#
#      defenceAggression  defenceAggressionClass defenceTeamWidth  \
# 0                   65                   Press               70
# 1                   47                   Press               54
# 2                   45                   Press               55
# 3                   45                   Press               55
# 4                   45                   Press               55
# ...                ...                     ...              ...
# 1453                45                   Press               49
# 1454                60                   Press               50
# 1455                43                   Press               55
# 1456                43                   Press               55
# 1457                44                   Press               55
#
#      defenceTeamWidthClass  defenceDefenderLineClass
# 0                     Wide                     Cover
# 1                   Normal              Offside Trap
# 2                   Normal                     Cover
# 3                   Normal                     Cover
# 4                   Normal                     Cover
# ...                    ...                       ...
# 1453                Normal                     Cover
# 1454                Normal                     Cover
# 1455                Normal                     Cover
# 1456                Normal                     Cover
# 1457                Normal                     Cover
#
# [1458 rows x 26 columns]

# %% [markdown]
# We can rename the column 'team_long_name' to just 'team' for easy management.

# %%
teams_attributes.rename(columns={"team_long_name": "team"}, inplace=True)
teams_attributes
# Out:
#       team_api_id                team    id  team_fifa_api_id  \
# 0            9987            KRC Genk   485               673
# 1            9987            KRC Genk   486               673
# 2            9987            KRC Genk   487               673
# 3            9987            KRC Genk   488               673
# 4            9987            KRC Genk   489               673
# ...           ...                 ...   ...               ...
# 1453         9777         Servette FC  1156               324
# 1454         7730  FC Lausanne-Sports   672              1862
# 1455         7730  FC Lausanne-Sports   673              1862
# 1456         7730  FC Lausanne-Sports   674              1862
# 1457         7730  FC Lausanne-Sports   675              1862
#
#                      date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# 0     2010-02-22 00:00:00                45              Balanced
# 1     2011-02-22 00:00:00                66              Balanced
# 2     2012-02-22 00:00:00                53              Balanced
# 3     2013-09-20 00:00:00                58              Balanced
# 4     2014-09-19 00:00:00                58              Balanced
# ...                   ...               ...                   ...
# 1453  2013-09-20 00:00:00                48              Balanced
# 1454  2010-02-22 00:00:00                30                  Slow
# 1455  2012-02-22 00:00:00                37              Balanced
# 1456  2013-09-20 00:00:00                51              Balanced
# 1457  2014-09-19 00:00:00                37              Balanced
#
#       buildUpPlayDribbling buildUpPlayDribblingClass  buildUpPlayPassing  ...  \
# 0                      NaN                    Little                  45  ...
# 1                      NaN                    Little                  52  ...
# 2                      NaN                    Little                  55  ...
# 3                      NaN                    Little                  38  ...
# 4                     52.0                    Normal                  38  ...
# ...                    ...                       ...                 ...  ...
# 1453                   NaN                    Little                  51  ...
# 1454                   NaN                    Little                  60  ...
# 1455                   NaN                    Little                  49  ...
# 1456                   NaN                    Little                  49  ...
# 1457                  55.0                    Normal                  49  ...
#
#      chanceCreationShooting chanceCreationShootingClass  \
# 0                        60                      Normal
# 1                        51                      Normal
# 2                        56                      Normal
# 3                        56                      Normal
# 4                        56                      Normal
# ...                     ...                         ...
# 1453                     45                      Normal
# 1454                     60                      Normal
# 1455                     48                      Normal
# 1456                     48                      Normal
# 1457                     52                      Normal
#
#       chanceCreationPositioningClass defencePressure  defencePressureClass  \
# 0                          Organised              70                  High
# 1                          Organised              48                Medium
# 2                          Organised              47                Medium
# 3                          Organised              47                Medium
# 4                          Organised              47                Medium
# ...                              ...             ...                   ...
# 1453                       Organised              49                Medium
# 1454                       Organised              55                Medium
# 1455                       Organised              43                Medium
# 1456                       Organised              43                Medium
# 1457                       Organised              46                Medium
#
#      defenceAggression  defenceAggressionClass defenceTeamWidth  \
# 0                   65                   Press               70
# 1                   47                   Press               54
# 2                   45                   Press               55
# 3                   45                   Press               55
# 4                   45                   Press               55
# ...                ...                     ...              ...
# 1453                45                   Press               49
# 1454                60                   Press               50
# 1455                43                   Press               55
# 1456                43                   Press               55
# 1457                44                   Press               55
#
#      defenceTeamWidthClass  defenceDefenderLineClass
# 0                     Wide                     Cover
# 1                   Normal              Offside Trap
# 2                   Normal                     Cover
# 3                   Normal                     Cover
# 4                   Normal                     Cover
# ...                    ...                       ...
# 1453                Normal                     Cover
# 1454                Normal                     Cover
# 1455                Normal                     Cover
# 1456                Normal                     Cover
# 1457                Normal                     Cover
#
# [1458 rows x 26 columns]

# %% [markdown]
# In order to make easy to analyze data, first, we can check the cleaness of the 'teams_attributes' dataset.
# We can start removing some columns like 'id' and 'team_fifa_api_id' because these columns do not contain relevant information.

# %%
teams_attributes.drop(columns=["id", "team_fifa_api_id"], inplace=True)
teams_attributes
# Out:
#       team_api_id                team                 date  buildUpPlaySpeed  \
# 0            9987            KRC Genk  2010-02-22 00:00:00                45
# 1            9987            KRC Genk  2011-02-22 00:00:00                66
# 2            9987            KRC Genk  2012-02-22 00:00:00                53
# 3            9987            KRC Genk  2013-09-20 00:00:00                58
# 4            9987            KRC Genk  2014-09-19 00:00:00                58
# ...           ...                 ...                  ...               ...
# 1453         9777         Servette FC  2013-09-20 00:00:00                48
# 1454         7730  FC Lausanne-Sports  2010-02-22 00:00:00                30
# 1455         7730  FC Lausanne-Sports  2012-02-22 00:00:00                37
# 1456         7730  FC Lausanne-Sports  2013-09-20 00:00:00                51
# 1457         7730  FC Lausanne-Sports  2014-09-19 00:00:00                37
#
#      buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# 0                 Balanced                   NaN                    Little
# 1                 Balanced                   NaN                    Little
# 2                 Balanced                   NaN                    Little
# 3                 Balanced                   NaN                    Little
# 4                 Balanced                  52.0                    Normal
# ...                    ...                   ...                       ...
# 1453              Balanced                   NaN                    Little
# 1454                  Slow                   NaN                    Little
# 1455              Balanced                   NaN                    Little
# 1456              Balanced                   NaN                    Little
# 1457              Balanced                  55.0                    Normal
#
#       buildUpPlayPassing buildUpPlayPassingClass buildUpPlayPositioningClass  \
# 0                     45                   Mixed                   Organised
# 1                     52                   Mixed                   Organised
# 2                     55                   Mixed                   Organised
# 3                     38                   Mixed                   Organised
# 4                     38                   Mixed                   Organised
# ...                  ...                     ...                         ...
# 1453                  51                   Mixed                   Organised
# 1454                  60                   Mixed                   Organised
# 1455                  49                   Mixed                   Organised
# 1456                  49                   Mixed                   Organised
# 1457                  49                   Mixed                   Organised
#
#       ...  chanceCreationShooting chanceCreationShootingClass  \
# 0     ...                      60                      Normal
# 1     ...                      51                      Normal
# 2     ...                      56                      Normal
# 3     ...                      56                      Normal
# 4     ...                      56                      Normal
# ...   ...                     ...                         ...
# 1453  ...                      45                      Normal
# 1454  ...                      60                      Normal
# 1455  ...                      48                      Normal
# 1456  ...                      48                      Normal
# 1457  ...                      52                      Normal
#
#       chanceCreationPositioningClass defencePressure  defencePressureClass  \
# 0                          Organised              70                  High
# 1                          Organised              48                Medium
# 2                          Organised              47                Medium
# 3                          Organised              47                Medium
# 4                          Organised              47                Medium
# ...                              ...             ...                   ...
# 1453                       Organised              49                Medium
# 1454                       Organised              55                Medium
# 1455                       Organised              43                Medium
# 1456                       Organised              43                Medium
# 1457                       Organised              46                Medium
#
#      defenceAggression defenceAggressionClass  defenceTeamWidth  \
# 0                   65                  Press                70
# 1                   47                  Press                54
# 2                   45                  Press                55
# 3                   45                  Press                55
# 4                   45                  Press                55
# ...                ...                    ...               ...
# 1453                45                  Press                49
# 1454                60                  Press                50
# 1455                43                  Press                55
# 1456                43                  Press                55
# 1457                44                  Press                55
#
#      defenceTeamWidthClass  defenceDefenderLineClass
# 0                     Wide                     Cover
# 1                   Normal              Offside Trap
# 2                   Normal                     Cover
# 3                   Normal                     Cover
# 4                   Normal                     Cover
# ...                    ...                       ...
# 1453                Normal                     Cover
# 1454                Normal                     Cover
# 1455                Normal                     Cover
# 1456                Normal                     Cover
# 1457                Normal                     Cover
#
# [1458 rows x 24 columns]

# %% [markdown]
# Let's check the null values of each column.

# %%
teams_attributes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1458 entries, 0 to 1457
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   team_api_id                     1458 non-null   int64
#  1   team                            1458 non-null   object
#  2   date                            1458 non-null   object
#  3   buildUpPlaySpeed                1458 non-null   int64
#  4   buildUpPlaySpeedClass           1458 non-null   object
#  5   buildUpPlayDribbling            489 non-null    float64
#  6   buildUpPlayDribblingClass       1458 non-null   object
#  7   buildUpPlayPassing              1458 non-null   int64
#  8   buildUpPlayPassingClass         1458 non-null   object
#  9   buildUpPlayPositioningClass     1458 non-null   object
#  10  chanceCreationPassing           1458 non-null   int64
#  11  chanceCreationPassingClass      1458 non-null   object
#  12  chanceCreationCrossing          1458 non-null   int64
#  13  chanceCreationCrossingClass     1458 non-null   object
#  14  chanceCreationShooting          1458 non-null   int64
#  15  chanceCreationShootingClass     1458 non-null   object
#  16  chanceCreationPositioningClass  1458 non-null   object
#  17  defencePressure                 1458 non-null   int64
#  18  defencePressureClass            1458 non-null   object
#  19  defenceAggression               1458 non-null   int64
#  20  defenceAggressionClass          1458 non-null   object
#  21  defenceTeamWidth                1458 non-null   int64
#  22  defenceTeamWidthClass           1458 non-null   object
#  23  defenceDefenderLineClass        1458 non-null   object
# dtypes: float64(1), int64(9), object(14)
# memory usage: 284.8+ KB

# %% [markdown]
# After displaying 'teams_attributes' dataframe info we can see column 'buildUpPlayDribbling' has just 489 non-null values, so there is not enough information in that particular column and it will be dismissed in the analysis.

# %%
teams_attributes.drop(columns=["buildUpPlayDribbling"], inplace=True)
teams_attributes.shape
# Out:
# (1458, 23)

# %%
teams_attributes
# Out:
#       team_api_id                team                 date  buildUpPlaySpeed  \
# 0            9987            KRC Genk  2010-02-22 00:00:00                45
# 1            9987            KRC Genk  2011-02-22 00:00:00                66
# 2            9987            KRC Genk  2012-02-22 00:00:00                53
# 3            9987            KRC Genk  2013-09-20 00:00:00                58
# 4            9987            KRC Genk  2014-09-19 00:00:00                58
# ...           ...                 ...                  ...               ...
# 1453         9777         Servette FC  2013-09-20 00:00:00                48
# 1454         7730  FC Lausanne-Sports  2010-02-22 00:00:00                30
# 1455         7730  FC Lausanne-Sports  2012-02-22 00:00:00                37
# 1456         7730  FC Lausanne-Sports  2013-09-20 00:00:00                51
# 1457         7730  FC Lausanne-Sports  2014-09-19 00:00:00                37
#
#      buildUpPlaySpeedClass buildUpPlayDribblingClass  buildUpPlayPassing  \
# 0                 Balanced                    Little                  45
# 1                 Balanced                    Little                  52
# 2                 Balanced                    Little                  55
# 3                 Balanced                    Little                  38
# 4                 Balanced                    Normal                  38
# ...                    ...                       ...                 ...
# 1453              Balanced                    Little                  51
# 1454                  Slow                    Little                  60
# 1455              Balanced                    Little                  49
# 1456              Balanced                    Little                  49
# 1457              Balanced                    Normal                  49
#
#      buildUpPlayPassingClass buildUpPlayPositioningClass  \
# 0                      Mixed                   Organised
# 1                      Mixed                   Organised
# 2                      Mixed                   Organised
# 3                      Mixed                   Organised
# 4                      Mixed                   Organised
# ...                      ...                         ...
# 1453                   Mixed                   Organised
# 1454                   Mixed                   Organised
# 1455                   Mixed                   Organised
# 1456                   Mixed                   Organised
# 1457                   Mixed                   Organised
#
#       chanceCreationPassing  ... chanceCreationShooting  \
# 0                        50  ...                     60
# 1                        65  ...                     51
# 2                        55  ...                     56
# 3                        67  ...                     56
# 4                        67  ...                     56
# ...                     ...  ...                    ...
# 1453                     53  ...                     45
# 1454                     40  ...                     60
# 1455                     52  ...                     48
# 1456                     52  ...                     48
# 1457                     52  ...                     52
#
#       chanceCreationShootingClass chanceCreationPositioningClass  \
# 0                          Normal                      Organised
# 1                          Normal                      Organised
# 2                          Normal                      Organised
# 3                          Normal                      Organised
# 4                          Normal                      Organised
# ...                           ...                            ...
# 1453                       Normal                      Organised
# 1454                       Normal                      Organised
# 1455                       Normal                      Organised
# 1456                       Normal                      Organised
# 1457                       Normal                      Organised
#
#       defencePressure defencePressureClass defenceAggression  \
# 0                  70                 High                65
# 1                  48               Medium                47
# 2                  47               Medium                45
# 3                  47               Medium                45
# 4                  47               Medium                45
# ...               ...                  ...               ...
# 1453               49               Medium                45
# 1454               55               Medium                60
# 1455               43               Medium                43
# 1456               43               Medium                43
# 1457               46               Medium                44
#
#       defenceAggressionClass defenceTeamWidth  defenceTeamWidthClass  \
# 0                      Press               70                   Wide
# 1                      Press               54                 Normal
# 2                      Press               55                 Normal
# 3                      Press               55                 Normal
# 4                      Press               55                 Normal
# ...                      ...              ...                    ...
# 1453                   Press               49                 Normal
# 1454                   Press               50                 Normal
# 1455                   Press               55                 Normal
# 1456                   Press               55                 Normal
# 1457                   Press               55                 Normal
#
#      defenceDefenderLineClass
# 0                       Cover
# 1                Offside Trap
# 2                       Cover
# 3                       Cover
# 4                       Cover
# ...                       ...
# 1453                    Cover
# 1454                    Cover
# 1455                    Cover
# 1456                    Cover
# 1457                    Cover
#
# [1458 rows x 23 columns]

# %% [markdown]
# Now, go back to the analysis of the duplicated teams' names. The first team found duplicated was 'Royal Excel Mouscron'.

# %%
teams_attributes[teams_attributes["team"] == "Royal Excel Mouscron"]
# Out:
#     team_api_id                  team                 date  buildUpPlaySpeed  \
# 68         9996  Royal Excel Mouscron  2015-09-10 00:00:00                50
# 69         9996  Royal Excel Mouscron  2015-09-10 00:00:00                50
# 96       274581  Royal Excel Mouscron  2015-09-10 00:00:00                50
#
#    buildUpPlaySpeedClass buildUpPlayDribblingClass  buildUpPlayPassing  \
# 68              Balanced                    Normal                  50
# 69              Balanced                    Normal                  50
# 96              Balanced                    Normal                  50
#
#    buildUpPlayPassingClass buildUpPlayPositioningClass  chanceCreationPassing  \
# 68                   Mixed                   Organised                     50
# 69                   Mixed                   Organised                     50
# 96                   Mixed                   Organised                     50
#
#     ... chanceCreationShooting  chanceCreationShootingClass  \
# 68  ...                     50                       Normal
# 69  ...                     50                       Normal
# 96  ...                     50                       Normal
#
#    chanceCreationPositioningClass  defencePressure defencePressureClass  \
# 68                      Organised               45               Medium
# 69                      Organised               45               Medium
# 96                      Organised               45               Medium
#
#    defenceAggression  defenceAggressionClass defenceTeamWidth  \
# 68                45                   Press               50
# 69                45                   Press               50
# 96                45                   Press               50
#
#     defenceTeamWidthClass defenceDefenderLineClass
# 68                 Normal                    Cover
# 69                 Normal                    Cover
# 96                 Normal                    Cover
#
# [3 rows x 23 columns]

# %% [markdown]
# Verify if the whole three rows have the same values except witht the column 'team_api_id':

# %%
teams_attributes \
    .loc[:, teams_attributes.columns[1:]] \
        .loc[teams_attributes["team"] == "Royal Excel Mouscron"] \
            .duplicated()
# Out:
# 68    False
# 69     True
# 96     True
# dtype: bool

# %% [markdown]
# Let's remove the rows that are duplicated except for the column 'team_api_id'.

# %%
teams_attributes.drop_duplicates(subset=teams_attributes.columns[1:], inplace=True)
teams_attributes
# Out:
#       team_api_id                team                 date  buildUpPlaySpeed  \
# 0            9987            KRC Genk  2010-02-22 00:00:00                45
# 1            9987            KRC Genk  2011-02-22 00:00:00                66
# 2            9987            KRC Genk  2012-02-22 00:00:00                53
# 3            9987            KRC Genk  2013-09-20 00:00:00                58
# 4            9987            KRC Genk  2014-09-19 00:00:00                58
# ...           ...                 ...                  ...               ...
# 1453         9777         Servette FC  2013-09-20 00:00:00                48
# 1454         7730  FC Lausanne-Sports  2010-02-22 00:00:00                30
# 1455         7730  FC Lausanne-Sports  2012-02-22 00:00:00                37
# 1456         7730  FC Lausanne-Sports  2013-09-20 00:00:00                51
# 1457         7730  FC Lausanne-Sports  2014-09-19 00:00:00                37
#
#      buildUpPlaySpeedClass buildUpPlayDribblingClass  buildUpPlayPassing  \
# 0                 Balanced                    Little                  45
# 1                 Balanced                    Little                  52
# 2                 Balanced                    Little                  55
# 3                 Balanced                    Little                  38
# 4                 Balanced                    Normal                  38
# ...                    ...                       ...                 ...
# 1453              Balanced                    Little                  51
# 1454                  Slow                    Little                  60
# 1455              Balanced                    Little                  49
# 1456              Balanced                    Little                  49
# 1457              Balanced                    Normal                  49
#
#      buildUpPlayPassingClass buildUpPlayPositioningClass  \
# 0                      Mixed                   Organised
# 1                      Mixed                   Organised
# 2                      Mixed                   Organised
# 3                      Mixed                   Organised
# 4                      Mixed                   Organised
# ...                      ...                         ...
# 1453                   Mixed                   Organised
# 1454                   Mixed                   Organised
# 1455                   Mixed                   Organised
# 1456                   Mixed                   Organised
# 1457                   Mixed                   Organised
#
#       chanceCreationPassing  ... chanceCreationShooting  \
# 0                        50  ...                     60
# 1                        65  ...                     51
# 2                        55  ...                     56
# 3                        67  ...                     56
# 4                        67  ...                     56
# ...                     ...  ...                    ...
# 1453                     53  ...                     45
# 1454                     40  ...                     60
# 1455                     52  ...                     48
# 1456                     52  ...                     48
# 1457                     52  ...                     52
#
#       chanceCreationShootingClass chanceCreationPositioningClass  \
# 0                          Normal                      Organised
# 1                          Normal                      Organised
# 2                          Normal                      Organised
# 3                          Normal                      Organised
# 4                          Normal                      Organised
# ...                           ...                            ...
# 1453                       Normal                      Organised
# 1454                       Normal                      Organised
# 1455                       Normal                      Organised
# 1456                       Normal                      Organised
# 1457                       Normal                      Organised
#
#       defencePressure defencePressureClass defenceAggression  \
# 0                  70                 High                65
# 1                  48               Medium                47
# 2                  47               Medium                45
# 3                  47               Medium                45
# 4                  47               Medium                45
# ...               ...                  ...               ...
# 1453               49               Medium                45
# 1454               55               Medium                60
# 1455               43               Medium                43
# 1456               43               Medium                43
# 1457               46               Medium                44
#
#       defenceAggressionClass defenceTeamWidth  defenceTeamWidthClass  \
# 0                      Press               70                   Wide
# 1                      Press               54                 Normal
# 2                      Press               55                 Normal
# 3                      Press               55                 Normal
# 4                      Press               55                 Normal
# ...                      ...              ...                    ...
# 1453                   Press               49                 Normal
# 1454                   Press               50                 Normal
# 1455                   Press               55                 Normal
# 1456                   Press               55                 Normal
# 1457                   Press               55                 Normal
#
#      defenceDefenderLineClass
# 0                       Cover
# 1                Offside Trap
# 2                       Cover
# 3                       Cover
# 4                       Cover
# ...                       ...
# 1453                    Cover
# 1454                    Cover
# 1455                    Cover
# 1456                    Cover
# 1457                    Cover
#
# [1450 rows x 23 columns]

# %% [markdown]
# We verify that we have the same unique teams' IDs and teams' names.

# %%
teams_attributes["team_api_id"].nunique()
# Out:
# 285

# %%
teams_attributes["team"].nunique()
# Out:
# 285

# %%
print("mean observations of attributes:", teams_attributes["team"].value_counts().mean())
print("max observations of attributes:", teams_attributes["team"].value_counts().max())
print("min observations of attributes:", teams_attributes["team"].value_counts().min())
# Out:
# mean observations of attributes: 5.087719298245614
# max observations of attributes: 6
# min observations of attributes: 1

# %%
teams_attributes["date"] = pd.to_datetime(teams_attributes["date"], format="%Y-%m-%d")
teams_attributes.dtypes
# Out:
# team_api_id                                int64
# team                                      object
# date                              datetime64[ns]
# buildUpPlaySpeed                           int64
# buildUpPlaySpeedClass                     object
# buildUpPlayDribblingClass                 object
# buildUpPlayPassing                         int64
# buildUpPlayPassingClass                   object
# buildUpPlayPositioningClass               object
# chanceCreationPassing                      int64
# chanceCreationPassingClass                object
# chanceCreationCrossing                     int64
# chanceCreationCrossingClass               object
# chanceCreationShooting                     int64
# chanceCreationShootingClass               object
# chanceCreationPositioningClass            object
# defencePressure                            int64
# defencePressureClass                      object
# defenceAggression                          int64
# defenceAggressionClass                    object
# defenceTeamWidth                           int64
# defenceTeamWidthClass                     object
# defenceDefenderLineClass                  object
# dtype: object

# %% [markdown]
# For what period of time we have attributes of teams?

# %%
teams_attributes["date"].min(), teams_attributes["date"].max()
# Out:
# (Timestamp('2010-02-22 00:00:00'), Timestamp('2015-09-10 00:00:00'))

# %%
matches = pd.read_csv("./matches.csv")
matches
# Out:
#           season        date  home_team_goal  away_team_goal      country  \
# 0      2008/2009  2008-08-17               1               1      Belgium
# 1      2008/2009  2008-08-16               0               0      Belgium
# 2      2008/2009  2008-08-16               0               3      Belgium
# 3      2008/2009  2008-08-17               5               0      Belgium
# 4      2008/2009  2008-08-16               1               3      Belgium
# ...          ...         ...             ...             ...          ...
# 25974  2015/2016  2015-09-22               1               0  Switzerland
# 25975  2015/2016  2015-09-23               1               2  Switzerland
# 25976  2015/2016  2015-09-23               2               0  Switzerland
# 25977  2015/2016  2015-09-22               0               0  Switzerland
# 25978  2015/2016  2015-09-23               4               3  Switzerland
#
#                          league                home_team          away_team
# 0        Belgium Jupiler League                 KRC Genk       Beerschot AC
# 1        Belgium Jupiler League         SV Zulte-Waregem   Sporting Lokeren
# 2        Belgium Jupiler League        KSV Cercle Brugge     RSC Anderlecht
# 3        Belgium Jupiler League                 KAA Gent          RAEC Mons
# 4        Belgium Jupiler League            FCV Dender EH  Standard de Liège
# ...                         ...                      ...                ...
# 25974  Switzerland Super League            FC St. Gallen            FC Thun
# 25975  Switzerland Super League                 FC Vaduz          FC Luzern
# 25976  Switzerland Super League  Grasshopper Club Zürich            FC Sion
# 25977  Switzerland Super League                   Lugano          FC Zürich
# 25978  Switzerland Super League           BSC Young Boys           FC Basel
#
# [25979 rows x 8 columns]

# %%
matches["date"] = pd.to_datetime(matches["date"], format="%Y-%m-%d")
seasons = matches.groupby(["season", "country"])["date"].agg(["min", "max"]).reset_index()
seasons
# Out:
#        season      country        min        max
# 0   2008/2009      Belgium 2008-08-16 2009-05-16
# 1   2008/2009      England 2008-08-16 2009-05-24
# 2   2008/2009       France 2008-08-09 2009-05-30
# 3   2008/2009      Germany 2008-08-15 2009-05-23
# 4   2008/2009        Italy 2008-08-30 2009-05-31
# ..        ...          ...        ...        ...
# 83  2015/2016       Poland 2015-07-17 2016-04-09
# 84  2015/2016     Portugal 2015-08-14 2016-05-15
# 85  2015/2016     Scotland 2015-08-01 2016-05-15
# 86  2015/2016        Spain 2015-08-21 2016-05-15
# 87  2015/2016  Switzerland 2015-07-18 2016-05-25
#
# [88 rows x 4 columns]

# %% [markdown]
# Read the table from csv to get the seasons and countries we have available.
# <!-- Read the table from csv and remove those teams that did not played the 8 seasons. -->

# %%
table = pd.read_csv("./table.csv")
table
# Out:
#          season             team      country  drawn  lost   won  played  for  \
# 0     2008/2009       1. FC Köln      Germany    6.0  17.0  11.0    34.0   35
# 1     2008/2009    AC Bellinzona  Switzerland   10.0  15.0  11.0    36.0   44
# 2     2008/2009     ADO Den Haag  Netherlands    8.0  18.0   8.0    34.0   41
# 3     2008/2009       AJ Auxerre       France    7.0  15.0  16.0    38.0   35
# 4     2008/2009        AS Monaco       France   12.0  15.0  11.0    38.0   41
# ...         ...              ...          ...    ...   ...   ...     ...  ...
# 1473  2015/2016  West Ham United      England   14.0   8.0  16.0    38.0   65
# 1474  2015/2016        Willem II  Netherlands   11.0  17.0   6.0    34.0   35
# 1475  2015/2016     Wisła Kraków       Poland   13.0   9.0   8.0    30.0   45
# 1476  2015/2016   Zagłębie Lubin       Poland    9.0   9.0  12.0    30.0   41
# 1477  2015/2016    Śląsk Wrocław       Poland   10.0  12.0   8.0    30.0   28
#
#       against  gd  points
# 0          50 -15    39.0
# 1          51  -7    43.0
# 2          58 -17    32.0
# 3          35   0    55.0
# 4          45  -4    45.0
# ...       ...  ..     ...
# 1473       51  14    62.0
# 1474       53 -18    29.0
# 1475       35  10    37.0
# 1476       37   4    45.0
# 1477       37  -9    34.0
#
# [1478 rows x 11 columns]

# %%
teams_labels = table["team"].unique()
teams_attributes = teams_attributes[teams_attributes["team"].isin(teams_labels)]
teams_attributes.reset_index(drop=True, inplace=True)
teams_attributes
# Out:
#       team_api_id                team       date  buildUpPlaySpeed  \
# 0            9987            KRC Genk 2010-02-22                45
# 1            9987            KRC Genk 2011-02-22                66
# 2            9987            KRC Genk 2012-02-22                53
# 3            9987            KRC Genk 2013-09-20                58
# 4            9987            KRC Genk 2014-09-19                58
# ...           ...                 ...        ...               ...
# 1445         9777         Servette FC 2013-09-20                48
# 1446         7730  FC Lausanne-Sports 2010-02-22                30
# 1447         7730  FC Lausanne-Sports 2012-02-22                37
# 1448         7730  FC Lausanne-Sports 2013-09-20                51
# 1449         7730  FC Lausanne-Sports 2014-09-19                37
#
#      buildUpPlaySpeedClass buildUpPlayDribblingClass  buildUpPlayPassing  \
# 0                 Balanced                    Little                  45
# 1                 Balanced                    Little                  52
# 2                 Balanced                    Little                  55
# 3                 Balanced                    Little                  38
# 4                 Balanced                    Normal                  38
# ...                    ...                       ...                 ...
# 1445              Balanced                    Little                  51
# 1446                  Slow                    Little                  60
# 1447              Balanced                    Little                  49
# 1448              Balanced                    Little                  49
# 1449              Balanced                    Normal                  49
#
#      buildUpPlayPassingClass buildUpPlayPositioningClass  \
# 0                      Mixed                   Organised
# 1                      Mixed                   Organised
# 2                      Mixed                   Organised
# 3                      Mixed                   Organised
# 4                      Mixed                   Organised
# ...                      ...                         ...
# 1445                   Mixed                   Organised
# 1446                   Mixed                   Organised
# 1447                   Mixed                   Organised
# 1448                   Mixed                   Organised
# 1449                   Mixed                   Organised
#
#       chanceCreationPassing  ... chanceCreationShooting  \
# 0                        50  ...                     60
# 1                        65  ...                     51
# 2                        55  ...                     56
# 3                        67  ...                     56
# 4                        67  ...                     56
# ...                     ...  ...                    ...
# 1445                     53  ...                     45
# 1446                     40  ...                     60
# 1447                     52  ...                     48
# 1448                     52  ...                     48
# 1449                     52  ...                     52
#
#       chanceCreationShootingClass chanceCreationPositioningClass  \
# 0                          Normal                      Organised
# 1                          Normal                      Organised
# 2                          Normal                      Organised
# 3                          Normal                      Organised
# 4                          Normal                      Organised
# ...                           ...                            ...
# 1445                       Normal                      Organised
# 1446                       Normal                      Organised
# 1447                       Normal                      Organised
# 1448                       Normal                      Organised
# 1449                       Normal                      Organised
#
#       defencePressure defencePressureClass defenceAggression  \
# 0                  70                 High                65
# 1                  48               Medium                47
# 2                  47               Medium                45
# 3                  47               Medium                45
# 4                  47               Medium                45
# ...               ...                  ...               ...
# 1445               49               Medium                45
# 1446               55               Medium                60
# 1447               43               Medium                43
# 1448               43               Medium                43
# 1449               46               Medium                44
#
#       defenceAggressionClass defenceTeamWidth  defenceTeamWidthClass  \
# 0                      Press               70                   Wide
# 1                      Press               54                 Normal
# 2                      Press               55                 Normal
# 3                      Press               55                 Normal
# 4                      Press               55                 Normal
# ...                      ...              ...                    ...
# 1445                   Press               49                 Normal
# 1446                   Press               50                 Normal
# 1447                   Press               55                 Normal
# 1448                   Press               55                 Normal
# 1449                   Press               55                 Normal
#
#      defenceDefenderLineClass
# 0                       Cover
# 1                Offside Trap
# 2                       Cover
# 3                       Cover
# 4                       Cover
# ...                       ...
# 1445                    Cover
# 1446                    Cover
# 1447                    Cover
# 1448                    Cover
# 1449                    Cover
#
# [1450 rows x 23 columns]

# %%
table["team"].nunique()
# Out:
# 296

# %%
teams_attributes["team"].nunique()
# Out:
# 285

# %%
teams_attributes = pd.merge(
    table[["team", "country"]].drop_duplicates().reset_index(drop=True),
    teams_attributes,
    on=["team"],
)
teams_attributes
# Out:
#             team  country  team_api_id       date  buildUpPlaySpeed  \
# 0     1. FC Köln  Germany         8722 2010-02-22                55
# 1     1. FC Köln  Germany         8722 2011-02-22                58
# 2     1. FC Köln  Germany         8722 2012-02-22                53
# 3     1. FC Köln  Germany         8722 2013-09-20                60
# 4     1. FC Köln  Germany         8722 2014-09-19                59
# ...          ...      ...          ...        ...               ...
# 1445     Watford  England         9817 2011-02-22                64
# 1446     Watford  England         9817 2012-02-22                66
# 1447     Watford  England         9817 2013-09-20                67
# 1448     Watford  England         9817 2014-09-19                61
# 1449     Watford  England         9817 2015-09-10                61
#
#      buildUpPlaySpeedClass buildUpPlayDribblingClass  buildUpPlayPassing  \
# 0                 Balanced                    Little                  65
# 1                 Balanced                    Little                  71
# 2                 Balanced                    Little                  53
# 3                 Balanced                    Little                  56
# 4                 Balanced                    Normal                  57
# ...                    ...                       ...                 ...
# 1445              Balanced                    Little                  53
# 1446              Balanced                    Little                  66
# 1447                  Fast                    Little                  45
# 1448              Balanced                    Normal                  56
# 1449              Balanced                    Little                  52
#
#      buildUpPlayPassingClass buildUpPlayPositioningClass  ...  \
# 0                      Mixed                   Organised  ...
# 1                       Long                   Organised  ...
# 2                      Mixed                   Organised  ...
# 3                      Mixed                   Organised  ...
# 4                      Mixed                   Organised  ...
# ...                      ...                         ...  ...
# 1445                   Mixed                   Organised  ...
# 1446                   Mixed                   Organised  ...
# 1447                   Mixed                   Organised  ...
# 1448                   Mixed                   Organised  ...
# 1449                   Mixed                   Organised  ...
#
#       chanceCreationShooting chanceCreationShootingClass  \
# 0                         60                      Normal
# 1                         50                      Normal
# 2                         57                      Normal
# 3                         57                      Normal
# 4                         59                      Normal
# ...                      ...                         ...
# 1445                      48                      Normal
# 1446                      60                      Normal
# 1447                      53                      Normal
# 1448                      55                      Normal
# 1449                      45                      Normal
#
#       chanceCreationPositioningClass defencePressure  defencePressureClass  \
# 0                          Organised              45                Medium
# 1                          Organised              40                Medium
# 2                          Organised              43                Medium
# 3                          Organised              43                Medium
# 4                          Organised              57                Medium
# ...                              ...             ...                   ...
# 1445                       Organised              44                Medium
# 1446                       Organised              48                Medium
# 1447                       Free Form              38                Medium
# 1448                       Free Form              38                Medium
# 1449                       Free Form              38                Medium
#
#      defenceAggression defenceAggressionClass  defenceTeamWidth  \
# 0                   55                  Press                70
# 1                   40                  Press                56
# 2                   55                  Press                67
# 3                   55                  Press                67
# 4                   46                  Press                54
# ...                ...                    ...               ...
# 1445                47                  Press                66
# 1446                50                  Press                45
# 1447                52                  Press                45
# 1448                52                  Press                45
# 1449                52                  Press                45
#
#      defenceTeamWidthClass  defenceDefenderLineClass
# 0                     Wide                     Cover
# 1                   Normal                     Cover
# 2                     Wide                     Cover
# 3                     Wide                     Cover
# 4                   Normal                     Cover
# ...                    ...                       ...
# 1445                Normal                     Cover
# 1446                Normal                     Cover
# 1447                Normal                     Cover
# 1448                Normal                     Cover
# 1449                Normal                     Cover
#
# [1450 rows x 24 columns]

# %% [markdown]
# Verify that in this merge operation we don't have null values.

# %%
teams_attributes.isna().sum()
# Out:
# team                              0
# country                           0
# team_api_id                       0
# date                              0
# buildUpPlaySpeed                  0
# buildUpPlaySpeedClass             0
# buildUpPlayDribblingClass         0
# buildUpPlayPassing                0
# buildUpPlayPassingClass           0
# buildUpPlayPositioningClass       0
# chanceCreationPassing             0
# chanceCreationPassingClass        0
# chanceCreationCrossing            0
# chanceCreationCrossingClass       0
# chanceCreationShooting            0
# chanceCreationShootingClass       0
# chanceCreationPositioningClass    0
# defencePressure                   0
# defencePressureClass              0
# defenceAggression                 0
# defenceAggressionClass            0
# defenceTeamWidth                  0
# defenceTeamWidthClass             0
# defenceDefenderLineClass          0
# dtype: int64

# %%
def get_season(country, date):
    mask = (seasons["min"] <= date) & (date <= seasons["max"]) & (seasons["country"] == country)
    season = seasons.loc[mask, "season"]
    return season.iloc[0] if len(season) else np.nan

# %%
teams_attributes["season"] = teams_attributes.apply(lambda x: get_season(x["country"], x["date"]), axis=1)
teams_attributes
# Out:
#             team  country  team_api_id       date  buildUpPlaySpeed  \
# 0     1. FC Köln  Germany         8722 2010-02-22                55
# 1     1. FC Köln  Germany         8722 2011-02-22                58
# 2     1. FC Köln  Germany         8722 2012-02-22                53
# 3     1. FC Köln  Germany         8722 2013-09-20                60
# 4     1. FC Köln  Germany         8722 2014-09-19                59
# ...          ...      ...          ...        ...               ...
# 1445     Watford  England         9817 2011-02-22                64
# 1446     Watford  England         9817 2012-02-22                66
# 1447     Watford  England         9817 2013-09-20                67
# 1448     Watford  England         9817 2014-09-19                61
# 1449     Watford  England         9817 2015-09-10                61
#
#      buildUpPlaySpeedClass buildUpPlayDribblingClass  buildUpPlayPassing  \
# 0                 Balanced                    Little                  65
# 1                 Balanced                    Little                  71
# 2                 Balanced                    Little                  53
# 3                 Balanced                    Little                  56
# 4                 Balanced                    Normal                  57
# ...                    ...                       ...                 ...
# 1445              Balanced                    Little                  53
# 1446              Balanced                    Little                  66
# 1447                  Fast                    Little                  45
# 1448              Balanced                    Normal                  56
# 1449              Balanced                    Little                  52
#
#      buildUpPlayPassingClass buildUpPlayPositioningClass  ...  \
# 0                      Mixed                   Organised  ...
# 1                       Long                   Organised  ...
# 2                      Mixed                   Organised  ...
# 3                      Mixed                   Organised  ...
# 4                      Mixed                   Organised  ...
# ...                      ...                         ...  ...
# 1445                   Mixed                   Organised  ...
# 1446                   Mixed                   Organised  ...
# 1447                   Mixed                   Organised  ...
# 1448                   Mixed                   Organised  ...
# 1449                   Mixed                   Organised  ...
#
#       chanceCreationShootingClass chanceCreationPositioningClass  \
# 0                          Normal                      Organised
# 1                          Normal                      Organised
# 2                          Normal                      Organised
# 3                          Normal                      Organised
# 4                          Normal                      Organised
# ...                           ...                            ...
# 1445                       Normal                      Organised
# 1446                       Normal                      Organised
# 1447                       Normal                      Free Form
# 1448                       Normal                      Free Form
# 1449                       Normal                      Free Form
#
#       defencePressure defencePressureClass  defenceAggression  \
# 0                  45               Medium                 55
# 1                  40               Medium                 40
# 2                  43               Medium                 55
# 3                  43               Medium                 55
# 4                  57               Medium                 46
# ...               ...                  ...                ...
# 1445               44               Medium                 47
# 1446               48               Medium                 50
# 1447               38               Medium                 52
# 1448               38               Medium                 52
# 1449               38               Medium                 52
#
#      defenceAggressionClass defenceTeamWidth  defenceTeamWidthClass  \
# 0                     Press               70                   Wide
# 1                     Press               56                 Normal
# 2                     Press               67                   Wide
# 3                     Press               67                   Wide
# 4                     Press               54                 Normal
# ...                     ...              ...                    ...
# 1445                  Press               66                 Normal
# 1446                  Press               45                 Normal
# 1447                  Press               45                 Normal
# 1448                  Press               45                 Normal
# 1449                  Press               45                 Normal
#
#      defenceDefenderLineClass     season
# 0                       Cover  2009/2010
# 1                       Cover  2010/2011
# 2                       Cover  2011/2012
# 3                       Cover  2013/2014
# 4                       Cover  2014/2015
# ...                       ...        ...
# 1445                    Cover  2010/2011
# 1446                    Cover  2011/2012
# 1447                    Cover  2013/2014
# 1448                    Cover  2014/2015
# 1449                    Cover  2015/2016
#
# [1450 rows x 25 columns]

# %%
teams_attributes.isna().sum()
# Out:
# team                               0
# country                            0
# team_api_id                        0
# date                               0
# buildUpPlaySpeed                   0
# buildUpPlaySpeedClass              0
# buildUpPlayDribblingClass          0
# buildUpPlayPassing                 0
# buildUpPlayPassingClass            0
# buildUpPlayPositioningClass        0
# chanceCreationPassing              0
# chanceCreationPassingClass         0
# chanceCreationCrossing             0
# chanceCreationCrossingClass        0
# chanceCreationShooting             0
# chanceCreationShootingClass        0
# chanceCreationPositioningClass     0
# defencePressure                    0
# defencePressureClass               0
# defenceAggression                  0
# defenceAggressionClass             0
# defenceTeamWidth                   0
# defenceTeamWidthClass              0
# defenceDefenderLineClass           0
# season                            16
# dtype: int64

# %%
teams_attributes[teams_attributes["season"].isna()]
# Out:
#                      team  country  team_api_id       date  buildUpPlaySpeed  \
# 109          Beerschot AC  Belgium         9993 2013-09-20                47
# 200        Club Brugge KV  Belgium         8342 2013-09-20                45
# 449              KAA Gent  Belgium         9991 2013-09-20                50
# 455              KRC Genk  Belgium         9987 2013-09-20                58
# 461     KSV Cercle Brugge  Belgium         9984 2013-09-20                53
# 468           KV Kortrijk  Belgium         8571 2013-09-20                42
# 474           KV Mechelen  Belgium         8203 2013-09-20                52
# 660             RAEC Mons  Belgium         9998 2013-09-20                50
# 689        RSC Anderlecht  Belgium         8635 2013-09-20                52
# 789      SV Zulte-Waregem  Belgium        10000 2013-09-20                54
# 818    Sporting Charleroi  Belgium         9986 2013-09-20                60
# 824      Sporting Lokeren  Belgium         9994 2013-09-20                67
# 842     Standard de Liège  Belgium         9985 2013-09-20                54
# 1167            Lierse SK  Belgium         9989 2013-09-20                69
# 1228  Oud-Heverlee Leuven  Belgium         1773 2013-09-20                52
# 1326     Waasland-Beveren  Belgium         8475 2013-09-20                62
#
#      buildUpPlaySpeedClass buildUpPlayDribblingClass  buildUpPlayPassing  \
# 109               Balanced                    Little                  39
# 200               Balanced                    Little                  48
# 449               Balanced                    Little                  37
# 455               Balanced                    Little                  38
# 461               Balanced                    Little                  40
# 468               Balanced                    Little                  40
# 474               Balanced                    Little                  33
# 660               Balanced                    Little                  50
# 689               Balanced                    Little                  41
# 789               Balanced                    Little                  51
# 818               Balanced                    Little                  53
# 824                   Fast                    Little                  52
# 842               Balanced                    Little                  62
# 1167                  Fast                    Little                  58
# 1228              Balanced                    Little                  50
# 1326              Balanced                    Little                  53
#
#      buildUpPlayPassingClass buildUpPlayPositioningClass  ...  \
# 109                    Mixed                   Organised  ...
# 200                    Mixed                   Organised  ...
# 449                    Mixed                   Organised  ...
# 455                    Mixed                   Organised  ...
# 461                    Mixed                   Organised  ...
# 468                    Mixed                   Organised  ...
# 474                    Short                   Organised  ...
# 660                    Mixed                   Organised  ...
# 689                    Mixed                   Organised  ...
# 789                    Mixed                   Organised  ...
# 818                    Mixed                   Organised  ...
# 824                    Mixed                   Organised  ...
# 842                    Mixed                   Organised  ...
# 1167                   Mixed                   Organised  ...
# 1228                   Mixed                   Organised  ...
# 1326                   Mixed                   Organised  ...
#
#       chanceCreationShootingClass chanceCreationPositioningClass  \
# 109                        Normal                      Organised
# 200                        Normal                      Organised
# 449                        Normal                      Free Form
# 455                        Normal                      Organised
# 461                        Normal                      Free Form
# 468                        Little                      Organised
# 474                        Normal                      Free Form
# 660                        Normal                      Organised
# 689                        Normal                      Organised
# 789                        Little                      Organised
# 818                        Normal                      Organised
# 824                        Normal                      Organised
# 842                        Normal                      Organised
# 1167                       Normal                      Free Form
# 1228                       Normal                      Organised
# 1326                       Normal                      Free Form
#
#       defencePressure defencePressureClass  defenceAggression  \
# 109                45               Medium                 46
# 200                43               Medium                 59
# 449                50               Medium                 53
# 455                47               Medium                 45
# 461                59               Medium                 47
# 468                46               Medium                 45
# 474                42               Medium                 60
# 660                46               Medium                 45
# 689                60               Medium                 43
# 789                44               Medium                 58
# 818                42               Medium                 48
# 824                45               Medium                 52
# 842                45               Medium                 60
# 1167               38               Medium                 49
# 1228               43               Medium                 44
# 1326               30                 Deep                 49
#
#      defenceAggressionClass defenceTeamWidth  defenceTeamWidthClass  \
# 109                   Press               67                   Wide
# 200                   Press               45                 Normal
# 449                   Press               40                 Normal
# 455                   Press               55                 Normal
# 461                   Press               62                 Normal
# 468                   Press               52                 Normal
# 474                   Press               52                 Normal
# 660                   Press               47                 Normal
# 689                   Press               65                 Normal
# 789                   Press               37                 Normal
# 818                   Press               49                 Normal
# 824                   Press               52                 Normal
# 842                   Press               52                 Normal
# 1167                  Press               65                 Normal
# 1228                  Press               50                 Normal
# 1326                  Press               35                 Normal
#
#      defenceDefenderLineClass  season
# 109                     Cover     NaN
# 200                     Cover     NaN
# 449                     Cover     NaN
# 455                     Cover     NaN
# 461                     Cover     NaN
# 468                     Cover     NaN
# 474                     Cover     NaN
# 660                     Cover     NaN
# 689                     Cover     NaN
# 789                     Cover     NaN
# 818                     Cover     NaN
# 824                     Cover     NaN
# 842                     Cover     NaN
# 1167                    Cover     NaN
# 1228                    Cover     NaN
# 1326                    Cover     NaN
#
# [16 rows x 25 columns]

# %%
teams_attributes.fillna(value={"season": "2013/2014"}, inplace=True)
teams_attributes.isna().sum()
# Out:
# team                              0
# country                           0
# team_api_id                       0
# date                              0
# buildUpPlaySpeed                  0
# buildUpPlaySpeedClass             0
# buildUpPlayDribblingClass         0
# buildUpPlayPassing                0
# buildUpPlayPassingClass           0
# buildUpPlayPositioningClass       0
# chanceCreationPassing             0
# chanceCreationPassingClass        0
# chanceCreationCrossing            0
# chanceCreationCrossingClass       0
# chanceCreationShooting            0
# chanceCreationShootingClass       0
# chanceCreationPositioningClass    0
# defencePressure                   0
# defencePressureClass              0
# defenceAggression                 0
# defenceAggressionClass            0
# defenceTeamWidth                  0
# defenceTeamWidthClass             0
# defenceDefenderLineClass          0
# season                            0
# dtype: int64

# %%
teams_attributes = pd.merge(
    table,
    teams_attributes,
    on=["team", "season", "country"],
    how="right",
)
teams_attributes
# Out:
#          season        team  country  drawn  lost   won  played   for  \
# 0     2009/2010  1. FC Köln  Germany   11.0  14.0   9.0    34.0  33.0
# 1     2010/2011  1. FC Köln  Germany    5.0  16.0  13.0    34.0  47.0
# 2     2011/2012  1. FC Köln  Germany    6.0  20.0   8.0    34.0  39.0
# 3     2013/2014  1. FC Köln  Germany    NaN   NaN   NaN     NaN   NaN
# 4     2014/2015  1. FC Köln  Germany   13.0  12.0   9.0    34.0  34.0
# ...         ...         ...      ...    ...   ...   ...     ...   ...
# 1445  2010/2011     Watford  England    NaN   NaN   NaN     NaN   NaN
# 1446  2011/2012     Watford  England    NaN   NaN   NaN     NaN   NaN
# 1447  2013/2014     Watford  England    NaN   NaN   NaN     NaN   NaN
# 1448  2014/2015     Watford  England    NaN   NaN   NaN     NaN   NaN
# 1449  2015/2016     Watford  England    9.0  17.0  12.0    38.0  40.0
#
#       against    gd  ...  chanceCreationShooting  chanceCreationShootingClass  \
# 0        42.0  -9.0  ...                      60                       Normal
# 1        62.0 -15.0  ...                      50                       Normal
# 2        75.0 -36.0  ...                      57                       Normal
# 3         NaN   NaN  ...                      57                       Normal
# 4        40.0  -6.0  ...                      59                       Normal
# ...       ...   ...  ...                     ...                          ...
# 1445      NaN   NaN  ...                      48                       Normal
# 1446      NaN   NaN  ...                      60                       Normal
# 1447      NaN   NaN  ...                      53                       Normal
# 1448      NaN   NaN  ...                      55                       Normal
# 1449     50.0 -10.0  ...                      45                       Normal
#
#      chanceCreationPositioningClass  defencePressure defencePressureClass  \
# 0                         Organised               45               Medium
# 1                         Organised               40               Medium
# 2                         Organised               43               Medium
# 3                         Organised               43               Medium
# 4                         Organised               57               Medium
# ...                             ...              ...                  ...
# 1445                      Organised               44               Medium
# 1446                      Organised               48               Medium
# 1447                      Free Form               38               Medium
# 1448                      Free Form               38               Medium
# 1449                      Free Form               38               Medium
#
#      defenceAggression  defenceAggressionClass defenceTeamWidth  \
# 0                   55                   Press               70
# 1                   40                   Press               56
# 2                   55                   Press               67
# 3                   55                   Press               67
# 4                   46                   Press               54
# ...                ...                     ...              ...
# 1445                47                   Press               66
# 1446                50                   Press               45
# 1447                52                   Press               45
# 1448                52                   Press               45
# 1449                52                   Press               45
#
#      defenceTeamWidthClass  defenceDefenderLineClass
# 0                     Wide                     Cover
# 1                   Normal                     Cover
# 2                     Wide                     Cover
# 3                     Wide                     Cover
# 4                   Normal                     Cover
# ...                    ...                       ...
# 1445                Normal                     Cover
# 1446                Normal                     Cover
# 1447                Normal                     Cover
# 1448                Normal                     Cover
# 1449                Normal                     Cover
#
# [1450 rows x 33 columns]

# %% [markdown]
# We can see that there are some null values after the merge, and that is because not all teams played in all seasons. So, we do not have data regarding points, goals, etc.

# %%
teams_attributes.dropna(inplace=True)
teams_attributes
# Out:
#          season             team  country  drawn  lost   won  played   for  \
# 0     2009/2010       1. FC Köln  Germany   11.0  14.0   9.0    34.0  33.0
# 1     2010/2011       1. FC Köln  Germany    5.0  16.0  13.0    34.0  47.0
# 2     2011/2012       1. FC Köln  Germany    6.0  20.0   8.0    34.0  39.0
# 4     2014/2015       1. FC Köln  Germany   13.0  12.0   9.0    34.0  34.0
# 5     2015/2016       1. FC Köln  Germany   13.0  11.0  10.0    34.0  38.0
# ...         ...              ...      ...    ...   ...   ...     ...   ...
# 1434  2015/2016        Frosinone    Italy    7.0  23.0   8.0    38.0  35.0
# 1436  2015/2016      GFC Ajaccio   France   13.0  17.0   8.0    38.0  37.0
# 1437  2015/2016  SV Darmstadt 98  Germany   11.0  14.0   9.0    34.0  38.0
# 1443  2015/2016    UD Las Palmas    Spain    8.0  18.0  12.0    38.0  45.0
# 1449  2015/2016          Watford  England    9.0  17.0  12.0    38.0  40.0
#
#       against    gd  ...  chanceCreationShooting  chanceCreationShootingClass  \
# 0        42.0  -9.0  ...                      60                       Normal
# 1        62.0 -15.0  ...                      50                       Normal
# 2        75.0 -36.0  ...                      57                       Normal
# 4        40.0  -6.0  ...                      59                       Normal
# 5        42.0  -4.0  ...                      71                         Lots
# ...       ...   ...  ...                     ...                          ...
# 1434     76.0 -41.0  ...                      50                       Normal
# 1436     58.0 -21.0  ...                      55                       Normal
# 1437     53.0 -15.0  ...                      45                       Normal
# 1443     53.0  -8.0  ...                      53                       Normal
# 1449     50.0 -10.0  ...                      45                       Normal
#
#      chanceCreationPositioningClass  defencePressure defencePressureClass  \
# 0                         Organised               45               Medium
# 1                         Organised               40               Medium
# 2                         Organised               43               Medium
# 4                         Organised               57               Medium
# 5                         Organised               42               Medium
# ...                             ...              ...                  ...
# 1434                      Organised               55               Medium
# 1436                      Organised               42               Medium
# 1437                      Organised               32                 Deep
# 1443                      Organised               53               Medium
# 1449                      Free Form               38               Medium
#
#      defenceAggression  defenceAggressionClass defenceTeamWidth  \
# 0                   55                   Press               70
# 1                   40                   Press               56
# 2                   55                   Press               67
# 4                   46                   Press               54
# 5                   56                   Press               51
# ...                ...                     ...              ...
# 1434                57                   Press               47
# 1436                46                   Press               53
# 1437                56                   Press               41
# 1443                39                   Press               57
# 1449                52                   Press               45
#
#      defenceTeamWidthClass  defenceDefenderLineClass
# 0                     Wide                     Cover
# 1                   Normal                     Cover
# 2                     Wide                     Cover
# 4                   Normal                     Cover
# 5                   Normal                     Cover
# ...                    ...                       ...
# 1434                Normal                     Cover
# 1436                Normal                     Cover
# 1437                Normal                     Cover
# 1443                Normal                     Cover
# 1449                Normal                     Cover
#
# [1066 rows x 33 columns]

# %%
teams_attributes.isna().sum()
# Out:
# season                            0
# team                              0
# country                           0
# drawn                             0
# lost                              0
# won                               0
# played                            0
# for                               0
# against                           0
# gd                                0
# points                            0
# team_api_id                       0
# date                              0
# buildUpPlaySpeed                  0
# buildUpPlaySpeedClass             0
# buildUpPlayDribblingClass         0
# buildUpPlayPassing                0
# buildUpPlayPassingClass           0
# buildUpPlayPositioningClass       0
# chanceCreationPassing             0
# chanceCreationPassingClass        0
# chanceCreationCrossing            0
# chanceCreationCrossingClass       0
# chanceCreationShooting            0
# chanceCreationShootingClass       0
# chanceCreationPositioningClass    0
# defencePressure                   0
# defencePressureClass              0
# defenceAggression                 0
# defenceAggressionClass            0
# defenceTeamWidth                  0
# defenceTeamWidthClass             0
# defenceDefenderLineClass          0
# dtype: int64

# %%
teams_attributes.shape
# Out:
# (1066, 33)

# %%
len(teams_attributes.columns)
# Out:
# 33

# %%
teams_attributes.dtypes
# Out:
# season                                    object
# team                                      object
# country                                   object
# drawn                                    float64
# lost                                     float64
# won                                      float64
# played                                   float64
# for                                      float64
# against                                  float64
# gd                                       float64
# points                                   float64
# team_api_id                                int64
# date                              datetime64[ns]
# buildUpPlaySpeed                           int64
# buildUpPlaySpeedClass                     object
# buildUpPlayDribblingClass                 object
# buildUpPlayPassing                         int64
# buildUpPlayPassingClass                   object
# buildUpPlayPositioningClass               object
# chanceCreationPassing                      int64
# chanceCreationPassingClass                object
# chanceCreationCrossing                     int64
# chanceCreationCrossingClass               object
# chanceCreationShooting                     int64
# chanceCreationShootingClass               object
# chanceCreationPositioningClass            object
# defencePressure                            int64
# defencePressureClass                      object
# defenceAggression                          int64
# defenceAggressionClass                    object
# defenceTeamWidth                           int64
# defenceTeamWidthClass                     object
# defenceDefenderLineClass                  object
# dtype: object

# %%
teams_attributes["buildUpPlaySpeedClass"].value_counts()
# Out:
# Balanced    841
# Fast        139
# Slow         86
# Name: buildUpPlaySpeedClass, dtype: int64

# %%
teams_attributes["buildUpPlayDribblingClass"].value_counts()
# Out:
# Little    735
# Normal    312
# Lots       19
# Name: buildUpPlayDribblingClass, dtype: int64

# %%
teams_attributes["buildUpPlayPassingClass"].value_counts()
# Out:
# Mixed    897
# Short    102
# Long      67
# Name: buildUpPlayPassingClass, dtype: int64

# %%
teams_attributes["buildUpPlayPositioningClass"].value_counts()
# Out:
# Organised    996
# Free Form     70
# Name: buildUpPlayPositioningClass, dtype: int64

# %%
teams_attributes["chanceCreationPassingClass"].value_counts()
# Out:
# Normal    896
# Risky     129
# Safe       41
# Name: chanceCreationPassingClass, dtype: int64

# %%
teams_attributes["chanceCreationCrossingClass"].value_counts()
# Out:
# Normal    873
# Lots      155
# Little     38
# Name: chanceCreationCrossingClass, dtype: int64

# %%
teams_attributes["chanceCreationShootingClass"].value_counts()
# Out:
# Normal    877
# Lots      157
# Little     32
# Name: chanceCreationShootingClass, dtype: int64

# %%
teams_attributes["chanceCreationPositioningClass"].value_counts()
# Out:
# Organised    935
# Free Form    131
# Name: chanceCreationPositioningClass, dtype: int64

# %%
teams_attributes["defencePressureClass"].value_counts()
# Out:
# Medium    910
# Deep      110
# High       46
# Name: defencePressureClass, dtype: int64

# %%
teams_attributes["defenceAggressionClass"].value_counts()
# Out:
# Press      924
# Double      76
# Contain     66
# Name: defenceAggressionClass, dtype: int64

# %%
teams_attributes["defenceTeamWidthClass"].value_counts()
# Out:
# Normal    940
# Wide       82
# Narrow     44
# Name: defenceTeamWidthClass, dtype: int64

# %%
teams_attributes["defenceDefenderLineClass"].value_counts()
# Out:
# Cover           989
# Offside Trap     77
# Name: defenceDefenderLineClass, dtype: int64

# %%
numerical_features = [
    "buildUpPlaySpeed",
    "buildUpPlayPassing",
    "chanceCreationPassing",
    "chanceCreationCrossing",
    "chanceCreationShooting",
    "defencePressure",
    "defenceAggression",
    "defenceTeamWidth",
]

# %% [markdown]
# First, in order to tackle the question 'what team attributes lead to the most victories?' we can face this as a classification problem, which means what attributes predict the if a team wins or not a match.
#
# We have 'matches' dataframe and 'team_attributes' dataframe. The observations for 'matches' dataframe are per match and the observations for 'team_attributes' are per season, so we'll merge the data per season.

# %%
numerical_attributes = teams_attributes[["season", "team", "country"] + numerical_features]
numerical_attributes
# Out:
#          season             team  country  buildUpPlaySpeed  \
# 0     2009/2010       1. FC Köln  Germany                55
# 1     2010/2011       1. FC Köln  Germany                58
# 2     2011/2012       1. FC Köln  Germany                53
# 4     2014/2015       1. FC Köln  Germany                59
# 5     2015/2016       1. FC Köln  Germany                59
# ...         ...              ...      ...               ...
# 1434  2015/2016        Frosinone    Italy                63
# 1436  2015/2016      GFC Ajaccio   France                48
# 1437  2015/2016  SV Darmstadt 98  Germany                59
# 1443  2015/2016    UD Las Palmas    Spain                48
# 1449  2015/2016          Watford  England                61
#
#       buildUpPlayPassing  chanceCreationPassing  chanceCreationCrossing  \
# 0                     65                     65                      40
# 1                     71                     42                      39
# 2                     53                     57                      44
# 4                     57                     53                      47
# 5                     65                     57                      36
# ...                  ...                    ...                     ...
# 1434                  46                     51                      50
# 1436                  52                     55                      53
# 1437                  77                     52                      77
# 1443                  44                     53                      42
# 1449                  52                     54                      42
#
#       chanceCreationShooting  defencePressure  defenceAggression  \
# 0                         60               45                 55
# 1                         50               40                 40
# 2                         57               43                 55
# 4                         59               57                 46
# 5                         71               42                 56
# ...                      ...              ...                ...
# 1434                      50               55                 57
# 1436                      55               42                 46
# 1437                      45               32                 56
# 1443                      53               53                 39
# 1449                      45               38                 52
#
#       defenceTeamWidth
# 0                   70
# 1                   56
# 2                   67
# 4                   54
# 5                   51
# ...                ...
# 1434                47
# 1436                53
# 1437                41
# 1443                57
# 1449                45
#
# [1066 rows x 11 columns]

# %%
teams_attributes["team"].nunique(), matches["home_team"].nunique()
# Out:
# (271, 296)

# %%
set(numerical_attributes["team"].unique()).issubset(set(matches["home_team"].unique()))
# Out:
# True

# %%
condlist = [
    np.array(matches["home_team_goal"] > matches["away_team_goal"]).reshape(-1, 1),
    np.array(matches["home_team_goal"] < matches["away_team_goal"]).reshape(-1, 1),
]

choicelist = [[3,0], [0, 3]]
points = pd.DataFrame(
    np.select(condlist=condlist, choicelist=choicelist, default=[1, 1]),
    columns=["home_team_points", "away_team_points"],
)
matches = pd.concat(
    [
        matches,
        points,
    ],
    axis=1,
)
matches
# Out:
#           season       date  home_team_goal  away_team_goal      country  \
# 0      2008/2009 2008-08-17               1               1      Belgium
# 1      2008/2009 2008-08-16               0               0      Belgium
# 2      2008/2009 2008-08-16               0               3      Belgium
# 3      2008/2009 2008-08-17               5               0      Belgium
# 4      2008/2009 2008-08-16               1               3      Belgium
# ...          ...        ...             ...             ...          ...
# 25974  2015/2016 2015-09-22               1               0  Switzerland
# 25975  2015/2016 2015-09-23               1               2  Switzerland
# 25976  2015/2016 2015-09-23               2               0  Switzerland
# 25977  2015/2016 2015-09-22               0               0  Switzerland
# 25978  2015/2016 2015-09-23               4               3  Switzerland
#
#                          league                home_team          away_team  \
# 0        Belgium Jupiler League                 KRC Genk       Beerschot AC
# 1        Belgium Jupiler League         SV Zulte-Waregem   Sporting Lokeren
# 2        Belgium Jupiler League        KSV Cercle Brugge     RSC Anderlecht
# 3        Belgium Jupiler League                 KAA Gent          RAEC Mons
# 4        Belgium Jupiler League            FCV Dender EH  Standard de Liège
# ...                         ...                      ...                ...
# 25974  Switzerland Super League            FC St. Gallen            FC Thun
# 25975  Switzerland Super League                 FC Vaduz          FC Luzern
# 25976  Switzerland Super League  Grasshopper Club Zürich            FC Sion
# 25977  Switzerland Super League                   Lugano          FC Zürich
# 25978  Switzerland Super League           BSC Young Boys           FC Basel
#
#        home_team_points  away_team_points
# 0                     1                 1
# 1                     1                 1
# 2                     0                 3
# 3                     3                 0
# 4                     0                 3
# ...                 ...               ...
# 25974                 3                 0
# 25975                 0                 3
# 25976                 3                 0
# 25977                 1                 1
# 25978                 3                 0
#
# [25979 rows x 10 columns]

# %%
statistics = pd.concat(
    [
        matches[["country", "season", "home_team", "home_team_points"]].rename(columns={"home_team": "team", "home_team_points": "points"}),
        matches[["country", "season", "away_team", "away_team_points"]].rename(columns={"away_team": "team", "away_team_points": "points"}),
    ],
    ignore_index=True,
)
statistics
# Out:
#            country     season               team  points
# 0          Belgium  2008/2009           KRC Genk       1
# 1          Belgium  2008/2009   SV Zulte-Waregem       1
# 2          Belgium  2008/2009  KSV Cercle Brugge       0
# 3          Belgium  2008/2009           KAA Gent       3
# 4          Belgium  2008/2009      FCV Dender EH       0
# ...            ...        ...                ...     ...
# 51953  Switzerland  2015/2016            FC Thun       0
# 51954  Switzerland  2015/2016          FC Luzern       3
# 51955  Switzerland  2015/2016            FC Sion       0
# 51956  Switzerland  2015/2016          FC Zürich       1
# 51957  Switzerland  2015/2016           FC Basel       0
#
# [51958 rows x 4 columns]

# %% [markdown]
# Remove the teams in 'statistics' dataframe for which we do not have attributes.

# %%
teams_with_attributes = teams_attributes["team"].unique()
statistics = statistics[statistics["team"].isin(teams_with_attributes)]
statistics
# Out:
#            country     season               team  points
# 0          Belgium  2008/2009           KRC Genk       1
# 1          Belgium  2008/2009   SV Zulte-Waregem       1
# 2          Belgium  2008/2009  KSV Cercle Brugge       0
# 3          Belgium  2008/2009           KAA Gent       3
# 5          Belgium  2008/2009        KV Mechelen       1
# ...            ...        ...                ...     ...
# 51953  Switzerland  2015/2016            FC Thun       0
# 51954  Switzerland  2015/2016          FC Luzern       3
# 51955  Switzerland  2015/2016            FC Sion       0
# 51956  Switzerland  2015/2016          FC Zürich       1
# 51957  Switzerland  2015/2016           FC Basel       0
#
# [51098 rows x 4 columns]

# %%
set(statistics["team"].unique()) == set(teams_attributes["team"].unique())
# Out:
# True

# %%
statistics["points"].value_counts()
# Out:
# 3    19214
# 0    18896
# 1    12988
# Name: points, dtype: int64

# %%
statistics.replace(to_replace={"points": {3: "won", 1: "drawn", 0: "lost"}}, inplace=True)
statistics
# Out:
# /tmp/ipykernel_65904/418106478.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            country     season               team points
# 0          Belgium  2008/2009           KRC Genk  drawn
# 1          Belgium  2008/2009   SV Zulte-Waregem  drawn
# 2          Belgium  2008/2009  KSV Cercle Brugge   lost
# 3          Belgium  2008/2009           KAA Gent    won
# 5          Belgium  2008/2009        KV Mechelen  drawn
# ...            ...        ...                ...    ...
# 51953  Switzerland  2015/2016            FC Thun   lost
# 51954  Switzerland  2015/2016          FC Luzern    won
# 51955  Switzerland  2015/2016            FC Sion   lost
# 51956  Switzerland  2015/2016          FC Zürich  drawn
# 51957  Switzerland  2015/2016           FC Basel   lost
#
# [51098 rows x 4 columns]

# %%
statistics.rename(columns={"points": "game_status"}, inplace=True)
statistics
# Out:
# /tmp/ipykernel_65904/495333763.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            country     season               team game_status
# 0          Belgium  2008/2009           KRC Genk       drawn
# 1          Belgium  2008/2009   SV Zulte-Waregem       drawn
# 2          Belgium  2008/2009  KSV Cercle Brugge        lost
# 3          Belgium  2008/2009           KAA Gent         won
# 5          Belgium  2008/2009        KV Mechelen       drawn
# ...            ...        ...                ...         ...
# 51953  Switzerland  2015/2016            FC Thun        lost
# 51954  Switzerland  2015/2016          FC Luzern         won
# 51955  Switzerland  2015/2016            FC Sion        lost
# 51956  Switzerland  2015/2016          FC Zürich       drawn
# 51957  Switzerland  2015/2016           FC Basel        lost
#
# [51098 rows x 4 columns]

# %% [markdown]
# Merge 'statistics' with 'team_attributes'.

# %%
df = pd.merge(
    statistics,
    numerical_attributes,
    on=["season", "country", "team"],
)
df
# Out:
#            country     season               team game_status  \
# 0          Belgium  2009/2010  Standard de Liège       drawn
# 1          Belgium  2009/2010  Standard de Liège         won
# 2          Belgium  2009/2010  Standard de Liège       drawn
# 3          Belgium  2009/2010  Standard de Liège         won
# 4          Belgium  2009/2010  Standard de Liège       drawn
# ...            ...        ...                ...         ...
# 37533  Switzerland  2015/2016     BSC Young Boys        lost
# 37534  Switzerland  2015/2016     BSC Young Boys         won
# 37535  Switzerland  2015/2016     BSC Young Boys         won
# 37536  Switzerland  2015/2016     BSC Young Boys         won
# 37537  Switzerland  2015/2016     BSC Young Boys        lost
#
#        buildUpPlaySpeed  buildUpPlayPassing  chanceCreationPassing  \
# 0                    53                  40                     55
# 1                    53                  40                     55
# 2                    53                  40                     55
# 3                    53                  40                     55
# 4                    53                  40                     55
# ...                 ...                 ...                    ...
# 37533                52                  64                     39
# 37534                52                  64                     39
# 37535                52                  64                     39
# 37536                52                  64                     39
# 37537                52                  64                     39
#
#        chanceCreationCrossing  chanceCreationShooting  defencePressure  \
# 0                          55                      65               70
# 1                          55                      65               70
# 2                          55                      65               70
# 3                          55                      65               70
# 4                          55                      65               70
# ...                       ...                     ...              ...
# 37533                      66                      46               44
# 37534                      66                      46               44
# 37535                      66                      46               44
# 37536                      66                      46               44
# 37537                      66                      46               44
#
#        defenceAggression  defenceTeamWidth
# 0                     70                65
# 1                     70                65
# 2                     70                65
# 3                     70                65
# 4                     70                65
# ...                  ...               ...
# 37533                 34                50
# 37534                 34                50
# 37535                 34                50
# 37536                 34                50
# 37537                 34                50
#
# [37538 rows x 12 columns]

# %%
df["game_status"].value_counts(dropna=False)
# Out:
# won      14138
# lost     13909
# drawn     9491
# Name: game_status, dtype: int64

# %%
df["game_status"].value_counts(normalize=True) * 100.0
# Out:
# won      37.663168
# lost     37.053120
# drawn    25.283713
# Name: game_status, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier
from sklearn.svm import SVC

# %%
X = df.loc[:, numerical_features]
X
# Out:
#        buildUpPlaySpeed  buildUpPlayPassing  chanceCreationPassing  \
# 0                    53                  40                     55
# 1                    53                  40                     55
# 2                    53                  40                     55
# 3                    53                  40                     55
# 4                    53                  40                     55
# ...                 ...                 ...                    ...
# 37533                52                  64                     39
# 37534                52                  64                     39
# 37535                52                  64                     39
# 37536                52                  64                     39
# 37537                52                  64                     39
#
#        chanceCreationCrossing  chanceCreationShooting  defencePressure  \
# 0                          55                      65               70
# 1                          55                      65               70
# 2                          55                      65               70
# 3                          55                      65               70
# 4                          55                      65               70
# ...                       ...                     ...              ...
# 37533                      66                      46               44
# 37534                      66                      46               44
# 37535                      66                      46               44
# 37536                      66                      46               44
# 37537                      66                      46               44
#
#        defenceAggression  defenceTeamWidth
# 0                     70                65
# 1                     70                65
# 2                     70                65
# 3                     70                65
# 4                     70                65
# ...                  ...               ...
# 37533                 34                50
# 37534                 34                50
# 37535                 34                50
# 37536                 34                50
# 37537                 34                50
#
# [37538 rows x 8 columns]

# %%
y = df["game_status"]
y
# Out:
# 0        drawn
# 1          won
# 2        drawn
# 3          won
# 4        drawn
#          ...
# 37533     lost
# 37534      won
# 37535      won
# 37536      won
# 37537     lost
# Name: game_status, Length: 37538, dtype: object

# %%
model1 = LogisticRegression(multi_class="ovr")
model1.fit(X, y)
# Out:
# LogisticRegression(multi_class='ovr')

# %%
from collections import Counter

# %%
predictions1 = model1.predict(X)
Counter(predictions1)
# Out:
# array(['won', 'won', 'won', ..., 'lost', 'lost', 'lost'], dtype=object)

# %%
model1.feature_names_in_
# Out:
# array(['buildUpPlaySpeed', 'buildUpPlayPassing', 'chanceCreationPassing',
#        'chanceCreationCrossing', 'chanceCreationShooting',
#        'defencePressure', 'defenceAggression', 'defenceTeamWidth'],
#       dtype=object)

# %%
model2 = LogisticRegression()
ovr = OneVsRestClassifier(model2)
ovr.fit(X, y)
# Out:
# OneVsRestClassifier(estimator=LogisticRegression())

# %%
predictions2 = ovr.predict(X)
predictions2
# Out:
# array(['won', 'won', 'won', ..., 'lost', 'lost', 'lost'], dtype='<U5')

# %%
model3 = SVC(decision_function_shape="ovo")
model3.fit(X, y)
# Out:
# SVC(decision_function_shape='ovo')

# %%
predictions3 = model3.predict(X)
predictions3
# Out:
# array(['lost', 'lost', 'lost', ..., 'won', 'won', 'won'], dtype=object)

# %%
model4 = SVC()
ovo = OneVsOneClassifier(model4)
ovo.fit(X, y)
# Out:
# OneVsOneClassifier(estimator=SVC())

# %%
predictions4 = ovo.predict(X)
predictions4
# Out:
# array(['lost', 'lost', 'lost', ..., 'won', 'won', 'won'], dtype=object)

# %%
print((y == predictions1).sum())
print((y == predictions2).sum())
print((y == predictions3).sum())
print((y == predictions4).sum())
# Out:
# 15543
# 15543
# 16988
# 16985

# %%
df2 = pd.concat(
    [y, pd.Series(predictions1)],
    ignore_index=True,
    axis=1,
).rename(columns={0: "y", 1: "predictions"})
df2

# %%
df2["equal"] = df2["y"] == df2["predictions"]
df2

# %%
df2.groupby(by=["y", "predictions"]).sum()

# %%
from collections import Counter

print(Counter(predictions1))
print(Counter(predictions2))
print(Counter(predictions3))
print(Counter(predictions4))
# Out:
# Counter({'won': 19768, 'lost': 17770})
# Counter({'won': 19768, 'lost': 17770})
# Counter({'lost': 22352, 'won': 15050, 'drawn': 136})
# Counter({'lost': 22352, 'won': 15080, 'drawn': 106})

# %%
len(predictions1), len(y)

# %% [markdown]
# Create a Logistic Regression using multinomial.

# %%
model_multinomial = LogisticRegression(multi_class="multinomial", solver="lbfgs", max_iter=1000)
model_multinomial.fit(X, y)

# %%
predictions_multinomial = model_multinomial.predict(X)

# %%
Counter(predictions_multinomial)

# %%
model_ovr = LogisticRegression(multi_class="ovr")
model_ovr.fit(X, y)

# %%
predictions_ovr = model_ovr.predict(X)
predictions_ovr

# %%
y = y.replace({"won": 3, "drawn": 1, "lost": 0})
y
# Out:
# 0        1
# 1        3
# 2        1
# 3        3
# 4        1
#         ..
# 37533    0
# 37534    3
# 37535    3
# 37536    3
# 37537    0
# Name: game_status, Length: 37538, dtype: int64

# %%
from random import random
from sklearn.datasets import make_classification

X_test, y_test = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, n_classes=3, random_state=1)
model_test = LogisticRegression(multi_class="ovr")
model_test.fit(X_test, y_test)
predictions_test = model_test.predict(X_test)
Counter(predictions_test)
# Out:
# Counter({1: 321, 0: 389, 2: 290})

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_std = scaler.fit_transform(X)
# X_std
model_scaled = LogisticRegression(multi_class="ovr")
model_scaled.fit(X_std, y)
predictions_scaled = model_scaled.predict(X_std)
Counter(predictions_scaled)
# Out:
# Counter({'won': 19768, 'lost': 17770})

# %%
X_std.shape
# Out:
# (37538, 8)

# %%
clf = OneVsRestClassifier(LogisticRegression())
clf.fit(X_std, y)
predictions_ovr = clf.predict(X_std)
Counter(predictions_ovr)
# Out:
# Counter({'won': 19768, 'lost': 17770})

# %%
Counter(y)
# Out:
# Counter({'drawn': 9491, 'won': 14138, 'lost': 13909})

# %%
from random import random
from sklearn.datasets import make_classification

X_test, y_test = make_classification(n_samples=37538, n_features=10, n_informative=5, n_redundant=5, n_classes=3, random_state=1)
model_test = LogisticRegression(multi_class="ovr")
model_test.fit(X, y)
predictions_test = model_test.predict(X)
Counter(predictions_test)
# Out:
# Counter({3: 19768, 0: 17770})

# %%
Counter(y_test)
# Out:
# Counter({1: 12514, 0: 12525, 2: 12499})

# %%
Counter(y.to_numpy())
# Out:
# Counter({1: 9491, 3: 14138, 0: 13909})
